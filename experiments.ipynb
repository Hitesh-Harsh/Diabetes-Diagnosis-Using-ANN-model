# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Getting the data

# %%
df = pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # Features Explanation
#
# ##### Pregnancies: Number of previous pregnancies
# ##### Glucose: Plasma glucose concentration
# ##### BloodPressure: Diastolic blood pressure
# ##### SkinThickess: Skin fold thickness measured from the triceps
# ##### Insulin: Blood serum insulin concentration
# ##### BMI: Body Mass Index
# ##### DiabetesPedigreeFunction: A summarized score that indicates the genetic predisposition of the patient for diabetes, as extrapolated from the patient's family record for diabetes
# ##### Age: Age in years
# ##### Outcome: The target variable we are trying to predict , 1 for patients that developed diabetes within 5 years of the initial measurement and 0 otherwise

# %% [markdown]
# # Data Visualizations

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Pregnancies'}>,
#         <Axes: title={'center': 'Glucose'}>,
#         <Axes: title={'center': 'BloodPressure'}>],
#        [<Axes: title={'center': 'SkinThickness'}>,
#         <Axes: title={'center': 'Insulin'}>,
#         <Axes: title={'center': 'BMI'}>],
#        [<Axes: title={'center': 'DiabetesPedigreeFunction'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Outcome'}>]], dtype=object)

# %%
import seaborn as sns
# create a subplot of 3x3
plt.subplots(3,3,figsize=(15,15))

# Plot a density plot for each variable
for idx, col in enumerate(df.columns):
    ax = plt.subplot(3,3,idx+1)
    ax.yaxis.set_ticklabels([])
    sns.distplot(df.loc[df.Outcome == 0][col], hist=False, axlabel= False, kde_kws={'linestyle':'-', 'color':'black', 'label':"No Diabetes"})
    sns.distplot(df.loc[df.Outcome == 1][col], hist=False, axlabel= False, kde_kws={'linestyle':'--', 'color':'black', 'label':"Diabetes"})
    ax.set_title(col)
    
#Hide the 9th subplot (bottom right since there are only 8 plots)
plt.subplot(3,3,9).set_visible(False)

plt.show()

# %% [markdown]
# 100mg/dL
#
# Dash line is Diabetics
# Solid line is non-Diabetics
# 150mg/dL

# %% [markdown]
# # Missing Data Handling

# %%
df.isnull().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %% [markdown]
# We don't have any Null values in our dataset

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
print("Number of rows with 0 values for each variable")
for col in df.columns:
  missing_rows = df.loc[df[col]==0].shape[0]

  print(col + ": "+str(missing_rows))
# Out:
# Number of rows with 0 values for each variable
# Pregnancies: 111
# Glucose: 5
# BloodPressure: 35
# SkinThickness: 227
# Insulin: 374
# BMI: 11
# DiabetesPedigreeFunction: 0
# Age: 0
# Outcome: 500

# %% [markdown]
# There are several techniques to handle these missing values:
#
# Remove (discard) any rows with missing values
#
# Replace the missing values with mean/median/mode of the non-missing values
#
# Predict the actual values using a separate machine learning model

# %%
#Replace 0 value with NaN
import numpy as np
df['Glucose'] = df['Glucose'].replace(0,np.nan)
df['BloodPressure'] = df['BloodPressure'].replace(0,np.nan)
df['SkinThickness'] = df['SkinThickness'].replace(0,np.nan)
df['Insulin'] = df['Insulin'].replace(0,np.nan)

df['BMI'] = df['BMI'].replace(0,np.nan)

# %% [markdown]
# # Data Standardization

# %%
print("Number of rows with 0 values for each variable")
for col in df.columns:
  missing_rows = df.loc[df[col]==0].shape[0]

  print(col + ": "+str(missing_rows))
# Out:
# Number of rows with 0 values for each variable
# Pregnancies: 111
# Glucose: 0
# BloodPressure: 0
# SkinThickness: 0
# Insulin: 0
# BMI: 0
# DiabetesPedigreeFunction: 0
# Age: 0
# Outcome: 500

# %%
# Replace Nan values with the mean of the non-missing values by using fillna()
df['Glucose'] = df['Glucose'].fillna(df['Glucose'].mean())
df['BloodPressure'] = df['BloodPressure'].fillna(df['BloodPressure'].mean())
df['SkinThickness'] = df['SkinThickness'].fillna(df['SkinThickness'].mean())
df['Insulin'] = df['Insulin'].fillna(df['Insulin'].mean())

df['BMI'] = df['BMI'].fillna(df['BMI'].mean())

# %% [markdown]
# The goal of data standardization is to transform the numeric variables so that each variable has zero mean and unit variance.
#
# Insulin and DiabetesPedigreeFunction have vastly different scales. The maximum value for Insulin is 846 while the maximum value for DiabetesPedigreeFunction is only 2.42

# %%
from sklearn import preprocessing
df_scaled = preprocessing.scale(df)
df_scaled = pd.DataFrame(df_scaled,columns=df.columns)
df_scaled['Outcome'] = df['Outcome']
df = df_scaled

df.describe().loc[['mean','std','max'],].round(2).abs()
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# mean         0.00     0.00            0.0           0.00     0.00  0.00
# std          1.00     1.00            1.0           1.00     1.00  1.00
# max          3.91     2.54            4.1           7.95     8.13  5.04
#
#       DiabetesPedigreeFunction   Age  Outcome
# mean                      0.00  0.00     0.35
# std                       1.00  1.00     0.48
# max                       5.88  4.06     1.00

# %% [markdown]
# # Data Splitting

# %% [markdown]
# # Training set: The neural network will be trained on this subset of the data
#  Validation set: This set of data allows us to perform hyperparameter tuning(That is, tuning the number of hidden layers) using an unbiased source of data
#
#  Testing set: The final evaluation of the neural network will be based on this subset of the data.
#
#  The purpose of splitting the data into training, testing and validation sets is to avoid overfitting and to provide an unbiased source of data for evaluating performance
#
# If we allocate most of our data for training purposes, model performance will increase at the detriment of our ability to avoid overfitting.
#
# If we allocate most of our data for validation and testing purposes, model performance will decrease as there might be insufficient data for training.
# There are some steps:
#
# Original data is 1st splitted into training (80%) and testing (20%)
# Training set is 2nd splitted into training set, validation set and testing set. Splitting data must be done at random
# First, let's separate the dataset into X(input features) and y(target variable)

# %%
from sklearn.model_selection import train_test_split
X = df.loc[:, df.columns != 'Outcome']
y = df.loc[:, 'Outcome']
# Split the data into training set(80%) and the testing set(20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Make a second split to create the final training set and the validation set
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size = 0.2)

# %% [markdown]
# # Data Modelling

# %%
from keras.models import Sequential
model = Sequential()

# %% [markdown]
# The first hidden layer will have 32 nodes.
#
# The input dimension will be 8 because there 8 columns in X_train

# %%
from keras.layers import Dense # Add the first Hidden layer
model.add(Dense(32, activation='relu', input_dim=8))
model.add(Dense(16, activation='relu'))# Add the second hidden layer
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# There are three different parameters we need to define for the training process
#
# Optimizer: Let's use the adam optimizer, which is a popular optimizer in Keras. For most datasets, the adam optimizer will work well without much tuning
#
# Loss function: We will use binary_crossentropy as our loss function since the problem at hand is a binary classification problem.
#
# Metrics: We will use accuracy (that is the percentage of correctly classified samples) as our evaluation metric.

# %%
# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

# %%
#Train the model for 200 epochs
model.fit(X_train,y_train,epochs=200)
# Out:
# Epoch 1/200
# 16/16 [==============================] - 1s 2ms/step - loss: 0.6637 - accuracy: 0.6151
# Epoch 2/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6011 - accuracy: 0.7169
# Epoch 3/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5559 - accuracy: 0.7413
# Epoch 4/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5204 - accuracy: 0.7556
# Epoch 5/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4966 - accuracy: 0.7637
# Epoch 6/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4784 - accuracy: 0.7780
# Epoch 7/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4660 - accuracy: 0.7821
# Epoch 8/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4564 - accuracy: 0.7902
# Epoch 9/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4472 - accuracy: 0.7902
# Epoch 10/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4399 - accuracy: 0.7902
# Epoch 11/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4334 - accuracy: 0.7943
# Epoch 12/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4289 - accuracy: 0.7923
# Epoch 13/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4246 - accuracy: 0.8024
# Epoch 14/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4185 - accuracy: 0.8004
# Epoch 15/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4154 - accuracy: 0.8024
# Epoch 16/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4115 - accuracy: 0.8045
# Epoch 17/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4080 - accuracy: 0.8004
# Epoch 18/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4054 - accuracy: 0.8065
# Epoch 19/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4029 - accuracy: 0.8106
# Epoch 20/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4000 - accuracy: 0.8147
# Epoch 21/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3977 - accuracy: 0.8126
# Epoch 22/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3939 - accuracy: 0.8208
# Epoch 23/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3921 - accuracy: 0.8248
# Epoch 24/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3902 - accuracy: 0.8228
# Epoch 25/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3876 - accuracy: 0.8289
# Epoch 26/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3845 - accuracy: 0.8269
# Epoch 27/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3828 - accuracy: 0.8269
# Epoch 28/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3807 - accuracy: 0.8289
# Epoch 29/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3788 - accuracy: 0.8371
# Epoch 30/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3764 - accuracy: 0.8350
# Epoch 31/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3743 - accuracy: 0.8330
# Epoch 32/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3728 - accuracy: 0.8310
# Epoch 33/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3701 - accuracy: 0.8289
# Epoch 34/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3675 - accuracy: 0.8289
# Epoch 35/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3659 - accuracy: 0.8330
# Epoch 36/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3641 - accuracy: 0.8350
# Epoch 37/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3623 - accuracy: 0.8310
# Epoch 38/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3600 - accuracy: 0.8432
# Epoch 39/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3595 - accuracy: 0.8391
# Epoch 40/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3563 - accuracy: 0.8452
# Epoch 41/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3543 - accuracy: 0.8432
# Epoch 42/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3537 - accuracy: 0.8391
# Epoch 43/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3511 - accuracy: 0.8432
# Epoch 44/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3498 - accuracy: 0.8452
# Epoch 45/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3477 - accuracy: 0.8432
# Epoch 46/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3462 - accuracy: 0.8411
# Epoch 47/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3440 - accuracy: 0.8513
# Epoch 48/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3434 - accuracy: 0.8473
# Epoch 49/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3428 - accuracy: 0.8534
# Epoch 50/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3397 - accuracy: 0.8493
# Epoch 51/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3385 - accuracy: 0.8513
# Epoch 52/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3367 - accuracy: 0.8493
# Epoch 53/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.8534
# Epoch 54/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3338 - accuracy: 0.8534
# Epoch 55/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3334 - accuracy: 0.8513
# Epoch 56/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3313 - accuracy: 0.8493
# Epoch 57/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3301 - accuracy: 0.8554
# Epoch 58/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3285 - accuracy: 0.8595
# Epoch 59/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3261 - accuracy: 0.8615
# Epoch 60/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3253 - accuracy: 0.8574
# Epoch 61/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3237 - accuracy: 0.8574
# Epoch 62/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3225 - accuracy: 0.8615
# Epoch 63/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3211 - accuracy: 0.8595
# Epoch 64/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3199 - accuracy: 0.8554
# Epoch 65/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3186 - accuracy: 0.8595
# Epoch 66/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3170 - accuracy: 0.8595
# Epoch 67/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3159 - accuracy: 0.8574
# Epoch 68/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3141 - accuracy: 0.8615
# Epoch 69/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3130 - accuracy: 0.8595
# Epoch 70/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3110 - accuracy: 0.8615
# Epoch 71/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3099 - accuracy: 0.8595
# Epoch 72/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3098 - accuracy: 0.8574
# Epoch 73/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3095 - accuracy: 0.8595
# Epoch 74/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3060 - accuracy: 0.8615
# Epoch 75/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.3049 - accuracy: 0.8656
# Epoch 76/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3039 - accuracy: 0.8635
# Epoch 77/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3022 - accuracy: 0.8615
# Epoch 78/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3015 - accuracy: 0.8635
# Epoch 79/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3029 - accuracy: 0.8697
# Epoch 80/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2995 - accuracy: 0.8574
# Epoch 81/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2983 - accuracy: 0.8635
# Epoch 82/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2955 - accuracy: 0.8676
# Epoch 83/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2944 - accuracy: 0.8676
# Epoch 84/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2943 - accuracy: 0.8635
# Epoch 85/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2917 - accuracy: 0.8656
# Epoch 86/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2916 - accuracy: 0.8717
# Epoch 87/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2901 - accuracy: 0.8656
# Epoch 88/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2879 - accuracy: 0.8717
# Epoch 89/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2878 - accuracy: 0.8778
# Epoch 90/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2863 - accuracy: 0.8778
# Epoch 91/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2858 - accuracy: 0.8737
# Epoch 92/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2839 - accuracy: 0.8758
# Epoch 93/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2818 - accuracy: 0.8798
# Epoch 94/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2825 - accuracy: 0.8819
# Epoch 95/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2791 - accuracy: 0.8819
# Epoch 96/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2798 - accuracy: 0.8819
# Epoch 97/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2786 - accuracy: 0.8778
# Epoch 98/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2760 - accuracy: 0.8859
# Epoch 99/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2748 - accuracy: 0.8839
# Epoch 100/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2739 - accuracy: 0.8798
# Epoch 101/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2724 - accuracy: 0.8859
# Epoch 102/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2717 - accuracy: 0.8819
# Epoch 103/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2703 - accuracy: 0.8859
# Epoch 104/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2693 - accuracy: 0.8839
# Epoch 105/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2673 - accuracy: 0.8859
# Epoch 106/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2667 - accuracy: 0.8880
# Epoch 107/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2646 - accuracy: 0.8859
# Epoch 108/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2647 - accuracy: 0.8839
# Epoch 109/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2634 - accuracy: 0.8819
# Epoch 110/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2615 - accuracy: 0.8778
# Epoch 111/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2605 - accuracy: 0.8859
# Epoch 112/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2606 - accuracy: 0.8880
# Epoch 113/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2578 - accuracy: 0.8880
# Epoch 114/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2564 - accuracy: 0.8819
# Epoch 115/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2579 - accuracy: 0.8819
# Epoch 116/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2543 - accuracy: 0.8839
# Epoch 117/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2538 - accuracy: 0.8839
# Epoch 118/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2526 - accuracy: 0.8839
# Epoch 119/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2515 - accuracy: 0.8880
# Epoch 120/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2529 - accuracy: 0.8941
# Epoch 121/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2523 - accuracy: 0.8961
# Epoch 122/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2499 - accuracy: 0.8900
# Epoch 123/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2473 - accuracy: 0.8880
# Epoch 124/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2457 - accuracy: 0.8839
# Epoch 125/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2445 - accuracy: 0.8880
# Epoch 126/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2425 - accuracy: 0.8880
# Epoch 127/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2412 - accuracy: 0.8900
# Epoch 128/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2405 - accuracy: 0.8982
# Epoch 129/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2414 - accuracy: 0.8900
# Epoch 130/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2388 - accuracy: 0.8921
# Epoch 131/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2379 - accuracy: 0.8921
# Epoch 132/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2364 - accuracy: 0.8921
# Epoch 133/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2348 - accuracy: 0.8921
# Epoch 134/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2351 - accuracy: 0.8921
# Epoch 135/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2316 - accuracy: 0.9002
# Epoch 136/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2325 - accuracy: 0.8880
# Epoch 137/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2300 - accuracy: 0.8961
# Epoch 138/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2292 - accuracy: 0.8941
# Epoch 139/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2287 - accuracy: 0.9002
# Epoch 140/200
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2270 - accuracy: 0.8921
# Epoch 141/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2251 - accuracy: 0.8961
# Epoch 142/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2255 - accuracy: 0.9022
# Epoch 143/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2225 - accuracy: 0.8961
# Epoch 144/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2230 - accuracy: 0.8982
# Epoch 145/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2211 - accuracy: 0.9022
# Epoch 146/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2189 - accuracy: 0.9002
# Epoch 147/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2191 - accuracy: 0.8982
# Epoch 148/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2165 - accuracy: 0.9063
# Epoch 149/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2167 - accuracy: 0.9002
# Epoch 150/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2148 - accuracy: 0.9063
# Epoch 151/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2140 - accuracy: 0.9063
# Epoch 152/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2125 - accuracy: 0.9063
# Epoch 153/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2120 - accuracy: 0.9104
# Epoch 154/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2100 - accuracy: 0.9084
# Epoch 155/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2105 - accuracy: 0.9022
# Epoch 156/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2089 - accuracy: 0.9124
# Epoch 157/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2080 - accuracy: 0.9043
# Epoch 158/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2063 - accuracy: 0.9104
# Epoch 159/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2054 - accuracy: 0.9124
# Epoch 160/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2049 - accuracy: 0.9145
# Epoch 161/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2035 - accuracy: 0.9084
# Epoch 162/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2035 - accuracy: 0.9104
# Epoch 163/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.2033 - accuracy: 0.9104
# Epoch 164/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1990 - accuracy: 0.9104
# Epoch 165/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1996 - accuracy: 0.9145
# Epoch 166/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1968 - accuracy: 0.9165
# Epoch 167/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1982 - accuracy: 0.9084
# Epoch 168/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2002 - accuracy: 0.9104
# Epoch 169/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1955 - accuracy: 0.9206
# Epoch 170/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1934 - accuracy: 0.9226
# Epoch 171/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1929 - accuracy: 0.9226
# Epoch 172/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1929 - accuracy: 0.9165
# Epoch 173/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1911 - accuracy: 0.9165
# Epoch 174/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1923 - accuracy: 0.9226
# Epoch 175/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1891 - accuracy: 0.9226
# Epoch 176/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1865 - accuracy: 0.9226
# Epoch 177/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1866 - accuracy: 0.9267
# Epoch 178/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1886 - accuracy: 0.9185
# Epoch 179/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1845 - accuracy: 0.9287
# Epoch 180/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1846 - accuracy: 0.9308
# Epoch 181/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1833 - accuracy: 0.9328
# Epoch 182/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1843 - accuracy: 0.9226
# Epoch 183/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1835 - accuracy: 0.9206
# Epoch 184/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1807 - accuracy: 0.9308
# Epoch 185/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1810 - accuracy: 0.9308
# Epoch 186/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1788 - accuracy: 0.9308
# Epoch 187/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1776 - accuracy: 0.9267
# Epoch 188/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1762 - accuracy: 0.9287
# Epoch 189/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1759 - accuracy: 0.9308
# Epoch 190/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1756 - accuracy: 0.9308
# Epoch 191/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1749 - accuracy: 0.9308
# Epoch 192/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1748 - accuracy: 0.9267
# Epoch 193/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1736 - accuracy: 0.9308
# Epoch 194/200
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1730 - accuracy: 0.9328
# Epoch 195/200
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1717 - accuracy: 0.9389
# Epoch 196/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1690 - accuracy: 0.9369
# Epoch 197/200
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1685 - accuracy: 0.9369
# Epoch 198/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1674 - accuracy: 0.9389
# Epoch 199/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1655 - accuracy: 0.9369
# Epoch 200/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1656 - accuracy: 0.9348

# %%
scores = model.evaluate(X_train,y_train)
print("Training Accuracy: %.2f%%\n" % (scores[1]*100))
scores = model.evaluate(X_test,y_test)
print("Testing Accuracy: %.2f%%\n" % (scores[1]*100))
# Out:
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1618 - accuracy: 0.9389
# Training Accuracy: 93.89%
#
# 5/5 [==============================] - 0s 1ms/step - loss: 0.9603 - accuracy: 0.6494
# Testing Accuracy: 64.94%

# %% [markdown]
# True negative: Actual class is negative (no diabetes), and the model predicted negative (no diabetes)
#
# False positive : Actual class is negative (no diabetes), but the model predicted positive (diabetes)
#
# False negative: Actual class is positive (diabetes) but the model predicted negative (no diabetes)
#
# True positive: Actual class is positive (diabetes), and the model predicted positive (diabetes)

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
y_test_pred = (model.predict(X_test) > 0.5).astype("int32")
c_matrix = confusion_matrix(y_test,y_test_pred)
ax = sns.heatmap(c_matrix, annot=True, xticklabels=['No Diabetes','Diabetes'], yticklabels=['No Diabetes','Diabetes'], cbar= False, cmap='Blues')
ax.set_xlabel("Prediction")
ax.set_ylabel("Actual")
# Out:
# 5/5 [==============================] - 0s 929us/step
# Text(50.72222222222221, 0.5, 'Actual')

# %% [markdown]
# True positive rate (TPR) = True positive / (True positive + false negative)
#
# False positive Rate (FPR) = False positive /(true Negative + False Positive)

# %% [markdown]
# # ROC Curve

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

y_test_pred_probs = model.predict(X_test)
FPR,TPR, _= roc_curve(y_test,y_test_pred_probs)
# Out:
# 5/5 [==============================] - 0s 1ms/step

# %%
plt.plot(FPR,TPR)
plt.plot([0,1],[0,1],'--',color='black')#diagonal line

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Out:
# Text(0, 0.5, 'True Positive Rate')

# %% [markdown]
# # Interpretation:
# The AUC value for this model seems to be greater than 0.7, indicating that the model performs better than random but is not perfect. The closer the curve is to the top left corner, the better the model is at distinguishing between patients with and without diabetes.
